# %%
# Task no :5

import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd  # Import Pandas

class BookScraper:
    def __init__(self):
        self.base_url = 'https://books.toscrape.com/catalogue/category/books/'

    def scrape_book_details(self, url):
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        book_details = []

        for book in soup.find_all('article', class_='product_pod'):
            title = book.h3.a.get('title')
            price = book.find('p', class_='price_color').get_text()
            availability = book.find('p', class_='instock availability').get_text().strip()
            image_url = book.img.get('src')
            rating = book.find('p', class_='star-rating')['class'][1]
            product_page_url = book.h3.a.get('href')

            book_info = {
                'Title': title,
                'Price': price,
                'Availability': availability,
                'Image URL': image_url,
                'Rating': rating,
                'Product Page URL': f'https://books.toscrape.com/catalogue/{product_page_url}'
            }
            book_details.append(book_info)

        return book_details

    def write_to_csv(self, data, filename):
        keys = data[0].keys() if data else []
        with open(filename, 'w', newline='', encoding='utf-8') as csv_file:
            writer = csv.DictWriter(csv_file, fieldnames=keys)
            writer.writeheader()
            writer.writerows(data)

    def convert_to_dataframe(self, filename):
        df = pd.read_csv(filename)  # Read CSV file using Pandas
        return df

    def scrape_books_for_category(self, category):
        url = f'{self.base_url}{category}/index.html'
        print(f"URL for '{category}' category: {url}")

        book_data = []
        page_number = 1
        total_columns = 0

        while total_columns < 100:
            page_url = f"{url}?page={page_number}"
            print(f"Scraping URL: {page_url}")  # Debugging line
            page_data = self.scrape_book_details(page_url)
            book_data.extend(page_data)
            total_columns += len(page_data)
            page_number += 1

        if total_columns > 100:
            excess = total_columns - 100
            book_data = book_data[:-excess]

        filename = f'{category}_books.csv'
        self.write_to_csv(book_data, filename)
        print(f"Books data for '{category}' category has been saved in '{filename}'.")

        dataframe = self.convert_to_dataframe(filename)
        print(f"Converted '{filename}' to Pandas DataFrame:")
        print(dataframe)

scraper = BookScraper()
categories = ['fiction_10', 'science-fiction_16', 'historical-fiction_4']
for category in categories:
    scraper.scrape_books_for_category(category)
# Out:
# URL for 'fiction_10' category: https://books.toscrape.com/catalogue/category/books/fiction_10/index.html
# Scraping URL: https://books.toscrape.com/catalogue/category/books/fiction_10/index.html?page=1
# Scraping URL: https://books.toscrape.com/catalogue/category/books/fiction_10/index.html?page=2
# Scraping URL: https://books.toscrape.com/catalogue/category/books/fiction_10/index.html?page=3
# Scraping URL: https://books.toscrape.com/catalogue/category/books/fiction_10/index.html?page=4
# Scraping URL: https://books.toscrape.com/catalogue/category/books/fiction_10/index.html?page=5
# Books data for 'fiction_10' category has been saved in 'fiction_10_books.csv'.
# Converted 'fiction_10_books.csv' to Pandas DataFrame:
#                                                 Title   Price Availability  \
# 0                                          Soumission  £50.10     In stock
# 1                         Private Paris (Private #10)  £47.61     In stock
# 2                        We Love You, Charlie Freeman  £50.27     In stock
# 3                                              Thirst  £17.27     In stock
# 4   The Murder That Never Was (Forensic Instincts #5)  £54.11     In stock
# ..                                                ...     ...          ...
# 95                             My Name Is Lucy Barton  £41.56     In stock
# 96                                      My Mrs. Brown  £24.48     In stock
# 97              Mr. Mercedes (Bill Hodges Trilogy #1)  £28.90     In stock
# 98                          I Am Pilgrim (Pilgrim #1)  £10.60     In stock
# 99                   Eligible (The Austen Project #4)  £27.09     In stock
#
#                                             Image URL Rating  \
# 0   ../../../../media/cache/3e/ef/3eef99c9d9adef34...    One
# 1   ../../../../media/cache/9d/05/9d0533bae1578846...   Five
# 2   ../../../../media/cache/5f/15/5f152afdbc42356e...   Five
# 3   ../../../../media/cache/c4/0a/c40a64f59e7487b1...   Five
# 4   ../../../../media/cache/dc/44/dc44f8e2aebac48c...  Three
# ..                                                ...    ...
# 95  ../../../../media/cache/ca/b1/cab150e556b5fab6...    One
# 96  ../../../../media/cache/e0/79/e07906c1e507055d...  Three
# 97  ../../../../media/cache/a7/f0/a7f092a7b79f848d...    One
# 98  ../../../../media/cache/ed/07/ed07c9e7c53d4f33...   Four
# 99  ../../../../media/cache/26/3b/263bf5d128bf1855...  Three
#
#                                      Product Page URL
# 0   https://books.toscrape.com/catalogue/../../../...
# 1   https://books.toscrape.com/catalogue/../../../...
# 2   https://books.toscrape.com/catalogue/../../../...
# 3   https://books.toscrape.com/catalogue/../../../...
# 4   https://books.toscrape.com/catalogue/../../../...
# ..                                                ...
# 95  https://books.toscrape.com/catalogue/../../../...
# 96  https://books.toscrape.com/catalogue/../../../...
# 97  https://books.toscrape.com/catalogue/../../../...
# 98  https://books.toscrape.com/catalogue/../../../...
# 99  https://books.toscrape.com/catalogue/../../../...
#
# [100 rows x 6 columns]
# URL for 'science-fiction_16' category: https://books.toscrape.com/catalogue/category/books/science-fiction_16/index.html
# Scraping URL: https://books.toscrape.com/catalogue/category/books/science-fiction_16/index.html?page=1
# Scraping URL: https://books.toscrape.com/catalogue/category/books/science-fiction_16/index.html?page=2
# Scraping URL: https://books.toscrape.com/catalogue/category/books/science-fiction_16/index.html?page=3
# Scraping URL: https://books.toscrape.com/catalogue/category/books/science-fiction_16/index.html?page=4
# Scraping URL: https://books.toscrape.com/catalogue/category/books/science-fiction_16/index.html?page=5
# Scraping URL: https://books.toscrape.com/catalogue/category/books/science-fiction_16/index.html?page=6
# Scraping URL: https://books.toscrape.com/catalogue/category/books/science-fiction_16/index.html?page=7
# Books data for 'science-fiction_16' category has been saved in 'science-fiction_16_books.csv'.
# Converted 'science-fiction_16_books.csv' to Pandas DataFrame:
#                                                 Title   Price Availability  \
# 0   Mesaerion: The Best Science Fiction Stories 18...  £37.59     In stock
# 1                                                Join  £35.67     In stock
# 2   William Shakespeare's Star Wars: Verily, A New...  £43.30     In stock
# 3                                         The Project  £10.65     In stock
# 4                                     Soft Apocalypse  £26.12     In stock
# ..                                                ...     ...          ...
# 95  Having the Barbarian's Baby (Ice Planet Barbar...  £34.96     In stock
# 96  Mesaerion: The Best Science Fiction Stories 18...  £37.59     In stock
# 97                                               Join  £35.67     In stock
# 98  William Shakespeare's Star Wars: Verily, A New...  £43.30     In stock
# 99                                        The Project  £10.65     In stock
#
#                                             Image URL Rating  \
# 0   ../../../../media/cache/09/a3/09a3aef48557576e...    One
# 1   ../../../../media/cache/93/63/9363f0065fbad568...   Five
# 2   ../../../../media/cache/02/37/0237b445efc18c55...   Four
# 3   ../../../../media/cache/10/6e/106e2fc7160712ed...    One
# 4   ../../../../media/cache/f0/06/f0060c756556b855...    Two
# ..                                                ...    ...
# 95  ../../../../media/cache/f4/83/f4835e9f3fdd8b81...   Four
# 96  ../../../../media/cache/09/a3/09a3aef48557576e...    One
# 97  ../../../../media/cache/93/63/9363f0065fbad568...   Five
# 98  ../../../../media/cache/02/37/0237b445efc18c55...   Four
# 99  ../../../../media/cache/10/6e/106e2fc7160712ed...    One
#
#                                      Product Page URL
# 0   https://books.toscrape.com/catalogue/../../../...
# 1   https://books.toscrape.com/catalogue/../../../...
# 2   https://books.toscrape.com/catalogue/../../../...
# 3   https://books.toscrape.com/catalogue/../../../...
# 4   https://books.toscrape.com/catalogue/../../../...
# ..                                                ...
# 95  https://books.toscrape.com/catalogue/../../../...
# 96  https://books.toscrape.com/catalogue/../../../...
# 97  https://books.toscrape.com/catalogue/../../../...
# 98  https://books.toscrape.com/catalogue/../../../...
# 99  https://books.toscrape.com/catalogue/../../../...
#
# [100 rows x 6 columns]
# URL for 'historical-fiction_4' category: https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html
# Scraping URL: https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html?page=1
# Scraping URL: https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html?page=2
# Scraping URL: https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html?page=3
# Scraping URL: https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html?page=4
# Scraping URL: https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html?page=5
# Books data for 'historical-fiction_4' category has been saved in 'historical-fiction_4_books.csv'.
# Converted 'historical-fiction_4_books.csv' to Pandas DataFrame:
#                                                 Title   Price Availability  \
# 0                                  Tipping the Velvet  £53.74     In stock
# 1   Forever and Forever: The Courtship of Henry Lo...  £29.69     In stock
# 2             A Flight of Arrows (The Pathfinders #2)  £55.53     In stock
# 3                               The House by the Lake  £36.95     In stock
# 4                                        Mrs. Houdini  £30.25     In stock
# ..                                                ...     ...          ...
# 95                             Voyager (Outlander #3)  £21.07     In stock
# 96                                       The Red Tent  £35.66     In stock
# 97                   The Last Painting of Sara de Vos  £55.55     In stock
# 98  The Guernsey Literary and Potato Peel Pie Society  £49.53     In stock
# 99                              Girl in the Blue Coat  £46.83     In stock
#
#                                             Image URL Rating  \
# 0   ../../../../media/cache/26/0c/260c6ae16bce31c8...    One
# 1   ../../../../media/cache/d6/58/d658a1485b130ff2...  Three
# 2   ../../../../media/cache/82/96/8296f92b70fb1daf...   Five
# 3   ../../../../media/cache/0d/cb/0dcb33d60b0e79ad...    One
# 4   ../../../../media/cache/0e/fe/0efe86960cdff718...   Five
# ..                                                ...    ...
# 95  ../../../../media/cache/b5/d8/b5d813da01f2ccd7...   Five
# 96  ../../../../media/cache/b2/8f/b28f211e50e74445...   Five
# 97  ../../../../media/cache/bf/fd/bffd473ab232c5f3...    Two
# 98  ../../../../media/cache/18/f7/18f7bf6366cd7a8b...    One
# 99  ../../../../media/cache/bf/7a/bf7a5bc1d1ebac5e...    Two
#
#                                      Product Page URL
# 0   https://books.toscrape.com/catalogue/../../../...
# 1   https://books.toscrape.com/catalogue/../../../...
# 2   https://books.toscrape.com/catalogue/../../../...
# 3   https://books.toscrape.com/catalogue/../../../...
# 4   https://books.toscrape.com/catalogue/../../../...
# ..                                                ...
# 95  https://books.toscrape.com/catalogue/../../../...
# 96  https://books.toscrape.com/catalogue/../../../...
# 97  https://books.toscrape.com/catalogue/../../../...
# 98  https://books.toscrape.com/catalogue/../../../...
# 99  https://books.toscrape.com/catalogue/../../../...
#
# [100 rows x 6 columns]
